# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("../sh24/recon_sh24-to-pzt_pth.pkl",allow_pickle=True)
D_2_24 = np.asarray(data['calib'][6]['c']).reshape(2,-1).T

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# D_2_24     ndarray    48x2: 96 elems, type `float64`, 768 bytes
# data       dict       n=5
# np         module     <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
